# %%
from __future__ import print_function
__author__ = "Federica B. Bianco, CUSP NYU 2018"

# Timur Mukhtarov helped me with Q2 and Q3

# %% [markdown]
# # Create a <i>reproducible research</i> chunk of code
#
# That means we want the reader to be able to reproduce every step of the work we do.
#
# If our work includes the use of stochastic processes and random variables that gets tricky: how do we assure the random draw gives the same number to the user that it gave to me? That is not random!
#
# That becomes possible because computers are unable to poduce truly random numbers. When we ask a computer to generate a random number, it will in fact generate a "pseudo random" number. The number will be randon in the sanse that it will be some number between, for example, 0 and 1 if we ask for a **uniform random distribution** or a number near 0 if we aks for a **Gaussian distribution with mean 0**. <i> But the sequence of pseudo-random numbers that a compujter generates will depend on its **seed**: if you know the seed you know all the numbers that are "randomely" drawn</i>.
#
# You can read more about pseudorandom number generation in this wikipedia article https://en.wikipedia.org/wiki/Pseudorandom_number_generator
#
# Fill in the empty cells below with code, as directed.

# %%
import os
import sys
import pylab as pl
# %pylab inline

# you can use the numpy library for random number generation: 
# http://docs.scipy.org/doc/numpy/reference/routines.random.html

import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ### give numpy as seed for this code to be reproducible
# (no points if this is wrong)
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
np.random.seed(6)
pl.hist(np.random.randn(1000))
np.random.randn?

# %% [markdown]
# ### 1. Generate random distributions. use the function
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html
# ### to generate 100 2-dimensional random datapoints in a gaussian distribution
#
# call the array ReprRand

# %%
# Generating 100 2-dimensional random datapoints in a gaussian distribution
ReprRand = np.random.randn(2,100)

print(ReprRand)
# Out:
# [[-0.31178367  0.72900392  0.21782079 -0.8990918  -2.48678065  0.91325152
#    1.12706373 -1.51409323  1.63929108 -0.4298936   2.63128056  0.60182225
#   -0.33588161  1.23773784  0.11112817  0.12915125  0.07612761 -0.15512816
#    0.63422534  0.810655    0.35480861  1.81259031 -1.3564758  -0.46363197
#    0.82465384 -1.17643148  1.56448966  0.71270509 -0.1810066   0.53419953
#   -0.58661296 -1.48185327  0.85724762  0.94309899  0.11444143 -0.02195668
#   -2.12714455 -0.83440747 -0.46550831  0.23371059  1.38503523 -0.51962709
#   -0.78015214  0.95560959 -0.12673638 -1.36861282  1.21848065 -0.85750144
#   -0.56147088 -1.0335199   0.35877096  1.07368134 -0.37550472  0.39636757
#   -0.47144628  2.33660781  1.50278553 -0.59545972  0.52834106  0.9398248
#    0.42628539 -0.75815703 -0.16236698  0.72680996  0.44408297 -0.85682264
#    0.44692842 -1.01464799 -2.1323234   0.17386307  0.95120126  0.44189739
#    1.46901739  1.74951635  0.35353062 -0.64333729 -0.04723705 -1.44903979
# ...

# %% [markdown]
# #### if you did this correctly the shape of ReprRand will be (2, 100)

# %%
# run this cell
ReprRand.shape
# Out:
# (2, 100)

# %% [markdown]
# ## 2. use the same function to generate 50 more random 2x100 numpy arrays and store them in ReprRandAll, all with different mean.
#
# np.random.randn creates a distribution with mean 0 and standard deviation 1 by default.
#
# To obtain a gaussian distribution with a mean different than 1 using np.random.randn you must add your new mean (it is explained in the function documentation for which I already gave you the link)
#
# If you want to change the standard deviation (sigma) as well you multiply the distribution by the new sigma.
#
# You can do it in a for loop. The first line of code I included generates an array of zeros that you can fill in with your new numbers.

# %%
ReprRandAll = np.zeros((50, 2, 100))  #shape (50,2,100) #Better than list, more efficient #alterntive np.empty(10)
for i in range(50):
    ReprRandAll[i] = np.random.randn(2, 100) + [i+1]  
    print(ReprRandAll[i][0], ReprRandAll[i][1]) #ReprRandAll[0] includes one 2x100 array, for ReprRandAll[0][0] represents array row 1x100
# Out:
# [ 0.49573302  2.05250993 -0.46705339  2.57410416  1.47233738  2.67693004
#  -0.6912109   2.42780744  1.92856046  1.33947011  0.13121795  1.35483766
#   1.2628088   0.39096521 -0.37105209 -0.06862477  0.46929928  2.13694227
#   2.18705819  2.69089583  1.49028137 -0.44553018  0.25689919 -0.15404442
#   0.74232593  2.37681404  0.82101927  0.56937009  1.52907247  1.73336413
#   1.96671585  0.0647259   0.12179174  0.54427174  1.74307591  1.19329784
#   0.02867666  2.89687218  0.45669605  0.87620532  0.90342115  0.17998539
#   0.96442327  1.05635041  1.26198812  1.31557223  0.46720966  0.07469757
#   2.09391977  0.7819833   2.09773759  1.45341959  3.68279527  0.90409208
#  -0.65417522  0.68461602  2.21164595  2.90117753  2.75080818  1.6689234
#   2.60372408  0.02014298  0.44877553  0.08898024  1.62139726  2.33253032
#   1.07035934  1.45182179  0.57819792  0.66998818  1.16409073  2.58430318
#   1.51728625  1.55873158  2.11862873  1.68783833  0.32428763  2.78467571
# ...

# %%
# run this cell
ReprRandAll.shape
# Out:
# (50, 2, 100)

# %% [markdown]
# ## 3. now plot them:
#
# you can use the matplotlib library, and the function scatter(), but that would plot everything in the same color unless you ask it not to. For convenience, let's use the function plot() which by default plots lines, and tell it to plot points (in addition plot is actually more efficient, so if you have a large dataset you may want to consider using plot with points for it anyways)
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# http://matplotlib.org/users/pyplot_tutorial.html

# %%
import pylab as pl
import matplotlib.pyplot as plt
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

for j in range(50):
    pl.plot(ReprRandAll[j][0], ReprRandAll[j][1], '+') 
    
plt.title('Figure 1: Plot showing 50 random 2x100 arrays with diff. means')
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Text(0,0.5,'Y axis')

# %% [markdown]
# Always add a caption to each of your homework figures.
# And remember to give your labels some names!
# This is a general rule. Without the caption or axis labels this portion of the HW will not get points. Make sure the font in the labels is large enough to be readable.
#
# ## Figure 1:
#
# [write a caption here]

# %% [markdown]
# ## Challenge
#
# It is easier to give the same mean and standard deviation to each dimension. Can you give two different values for the mean along the x- and the mean along the y- axis for each of the 50 distributions if you have not done so? If you are an experienced coder, can you do it in a single line?

# %%
ReprRandAll2 = [ np.random.randn(50,2,100) + [i+1] for i in range(50)]

# %%
ReprRandAll2
# Out:
# [array([[[ 0.76995146,  2.87674131,  1.19918457, ...,  0.00479698,
#            1.72239994, -0.15308598],
#          [ 2.29616317,  0.97233015,  1.460059  , ...,  1.50513768,
#            2.47484912,  0.28487849]],
#
#         [[ 0.01112074,  0.46467195,  1.02860946, ...,  0.86422573,
#            1.78241426,  1.20664373],
#          [ 0.59957937,  1.99362283,  1.51643332, ...,  0.3436815 ,
#            4.01884391, -0.8454833 ]],
#
#         [[-0.5612982 , -1.40746459,  0.2643589 , ..., -0.13436396,
#            1.87786644,  2.40920422],
#          [ 2.7360738 ,  1.03889865,  1.96597559, ..., -0.02393442,
#            2.30643964, -0.39728153]],
#
#         ...,
#         [[ 0.60934172, -0.16649032, -0.96056857, ...,  2.54764558,
#            1.41672661,  1.38096796],
#          [-0.4531763 ,  1.82325806,  2.61332803, ...,  0.37859098,
#            0.60252448, -0.123357  ]],
#
#         [[ 0.14142729,  1.04476656, -1.5142949 , ...,  2.1940395 ,
#           -0.32373876,  1.70768746],
# ...

# %%
for j in range(50):
    pl.plot(ReprRandAll2[j][0], ReprRandAll2[j][1], '.')

plt.xlabel('X numbers')
plt.ylabel('Y numbers')
plt.title('Figure 2')
# Out:
# Text(0.5,1,'Figure 2')
